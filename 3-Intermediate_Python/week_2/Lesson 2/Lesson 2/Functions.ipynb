# %%
# Functions
import math
import os

# %%
# Simple function with no return value
def simpleFunction():
    print("Hello world!")
    
print(simpleFunction())
# Out:
# Hello world!
# None

# %%
for x in range(5):
    simpleFunction()
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!

# %%
# function with parameters and a return value
def areaOfRectangle(length, width):
    return length * width

print(areaOfRectangle(5, 6))

# Named parameters
print(areaOfRectangle(length=7, width=8))

w = 10
l = 6
# Named parameter order unimportant
print(areaOfRectangle(width=w, length=l))

# However, if you mix and match positional and named arguments, positional MUST come first
print(areaOfRectangle(l, width=w))
# Out:
# 30
# 56
# 60
# 60

# %%
# default parameters
def power(base, pow = 2):
    result = base**pow
    return result
    
print(power(5,3))
print(power(3))   # pow defaults to 2
# Out:
# 125
# 9

# %%
# returning multilpe items
def rectToPolar(x, y):
    r = power(power(x,2) + power(y,2), 0.5)  # or:  r = (x ** 2 + y ** 2) ** 0.5
    theta = math.atan2(y, x)
    return r, theta
    
x = 5
y = 5
r, angle = rectToPolar(x, y)
print(f"({x}, {y}) = radius: {r:.4f}, angle: {angle:.4f}")
# Out:
# (5, 5) = radius: 7.0711, angle: 0.7854

# %%
# function with a docstring
# No one standard: https://stackoverflow.com/questions/3898572/what-is-the-standard-python-docstring-format
def areaOfCircle(radius):
    """Calculate the area of a circle. (Numpy style)

    This method calculates the area of a circle using the standard formula: A=πr².

    Parameters
    ----------
    radius : float
        radius of the circle to get area for

    Returns
    -------
    float
        Area of the circle
    
    Examples
    --------
    >>> r=10
    >>> print (areaOfCircle(r))
    314.1592653589793
    """
    return math.pi * power(radius)  # pow defaults to 2

# %%
areaOfCircle(10)
# Out:
# 314.1592653589793

# %%
# Get just the docstring with no help header
print(areaOfCircle.__doc__)
# Out:
# Calculate the area of a circle. (Numpy style)
#
#     This method calculates the area of a circle using the standard formula: A=πr².
#
#     Parameters
#     ----------
#     radius : float
#         radius of the circle to get area for
#
#     Returns
#     -------
#     float
#         Area of the circle
#
#     Examples
#     --------
#     >>> r=10
#     >>> print (areaOfCircle(r))
#     314.1592653589793

# %%
# docstring in help format (notice the function prototype before the docstring output)
help (areaOfCircle)
# Out:
# Help on function areaOfCircle in module __main__:
#
# areaOfCircle(radius)
#     Calculate the area of a circle. (Numpy style)
#
#     This method calculates the area of a circle using the standard formula: A=πr².
#
#     Parameters
#     ----------
#     radius : float
#         radius of the circle to get area for
#
#     Returns
#     -------
#     float
#         Area of the circle
#
#     Examples
#     --------
#     >>> r=10
#     >>> print (areaOfCircle(r))
#     314.1592653589793

# %%
# n! = n * (n-1) * (n-2) * ... * 1
# 5! = 5 * 4 * 3 * 2 * 1

# iterative function:
# def factorial(value):
#     total = 1
#     for x in range(value):
#         total = total * (x + 1)
#     return total

# recursive function:
def factorial(value):
    """Calculates the factorial of a number n!. (Sphinx Style)

    :param value: value to get factorial for
    :returns: the factorial of a number
    """
    if value <= 1:
        return 1
    return value * factorial(value - 1)

# %%
factorial(10)
# Out:
# 3628800

# %%
help(factorial)
# Out:
# Help on function factorial in module __main__:
#
# factorial(value)
#     Calculates the factorial of a number n!. (Sphinx Style)
#
#     :param value: value to get factorial for
#     :returns: the factorial of a number

# %%
def printPath(path, level = 0, indentation = 4):
    '''
    Prints the given path and its child paths (Google style)

    Args:
        path (str): The file system path to print
        level(int): The nested level of the folder, used for indentation
        indentation(int): The indentation amount per nested level
    Returns:
        None
    '''
    with os.scandir(path) as scanResults:
        for entry in scanResults:
            if entry.is_dir():
                print(f"{'':<{level * indentation}}{entry.name:}")
                printPath(path + "\\" + entry.name, level + 1, indentation)

# %%
printPath("D:\OneDrive\dev", indentation = 2)  # Make sure you use a directory that exists!
# Out:
# codeblocks16
#   MinGW
#     bin
#     doc
#       runtime
#     include
#       ddk
#       gdiplus
#       GL
#       sys
#     lib
#       gcc
#         mingw32
#           4.9.2
#             include
#               c++
#                 backward
#                 bits
#                 debug
#                 decimal
#                 experimental
#                 ext
#                   pb_ds
#                     detail
#                       binary_heap_
#                       binomial_heap_
#                       binomial_heap_base_
#                       bin_search_tree_
#                       branch_policy
#                       cc_hash_table_map_
#                       eq_fn
#                       gp_hash_table_map_
#                       hash_fn
#                       left_child_next_sibling_heap_
#                       list_update_map_
#                       list_update_policy
#                       ov_tree_map_
#                       pairing_heap_
#                       pat_trie_
#                       rb_tree_map_
#                       rc_binomial_heap_
#                       resize_policy
#                       splay_tree_
#                       thin_heap_
#                       tree_policy
#                       trie_policy
#                       unordered_iterator
#                 mingw32
#                   bits
#                   ext
#                 parallel
#                 profile
#                   impl
#                 tr1
#                 tr2
#               ssp
#             include-fixed
#             install-tools
#               include
#     libexec
#       gcc
#         mingw32
#           4.9.2
#             install-tools
#     mingw32
#       bin
#       lib
#         ldscripts
#     share
#       doc
#         make
#           3.82.90
#         MinGW
#       gcc-4.9.2
#         python
#           libstdcxx
#             v6
#       gdb
#         python
#           gdb
#             command
#             function
#         syscalls
#       info
#       man
#         man1
#         man3
#         man7
#   share
#     CodeBlocks
#       compilers
#       docs
#       images
#         16x16
#         codecompletion
#         codesnippets
#         DoxyBlocks
#           16x16
#         fortranproject
#         settings
#         ThreadSearch
#           16x16
#           22x22
#         wxsmith
#       lexers
#       lib_finder
#       plugins
#       scripts
#       SpellChecker
#       templates
#         wizard
#           arm
#             files
#               ARM-eval7t
#                 h
#                 ld
#                 src
#               ek-at91sam7a3
#                 h
#                 ld
#                 src
#               lpd-lh7a404
#                 h
#                 ld
#                 src
#               olimex-at91sam7sx
#                 h
#                 ld
#                 src
#               olimex-lpc213x
#                 h
#                 ld
#                 src
#               phyCORE-AT91M55800
#                 h
#                 ld
#                 src
#               phyCORE-LPC2294
#                 h
#                 ld
#                 src
#               phyCORE-PXA255
#                 h
#                 ld
#                 src
#           avr
#             files
#           console
#             c
#             cpp
#           c_file
#           d
#             console
#           directx
#             dx8
#             dx9
#           dll
#             files
#           empty
#           empty_file
#           fltk
#             files
#             fluid
#           fortran
#             app
#               files
#             dll
#               files
#             file
#             lib
#               files
#           glfw
#             files
#           glut
#             files
#           gtk
#             files
#           h_file
#           irrlicht
#             files
#           lf
#             files
#               quick
#               structured
#           matlab_csf
#             files
#             lccstub
#           mcs51
#             files
#           ogre
#             files
#           opencv
#             files
#           opengl
#             files_unix
#             files_win
#           plugins
#             templates
#           ppc
#             files
#               MPC5200
#                 h
#                 ld
#                 src
#               MPC565
#                 h
#                 ld
#                 src
#           qt4
#             files
#           sdl
#             files
#           sfml
#             sfml1
#             sfml2
#           sharedlib
#             c
#             cpp
#           smartwin
#             files
#           staticlib
#             files
#           stlport
#             files
#           sys
#             files
#           tricore
#             templates
#               EasyKit-TC1767
#               EasyRun-TC1796
#                 h
#                 src
#               phyCORE-TC1130
#                 h
#                 src
#               phyCORE-TC1775
#                 h
#                 src
#               TriBoard-TC1130
#                 h
#                 src
#               TriBoard-TC1161
#               TriBoard-TC1162
#               TriBoard-TC1762
#               TriBoard-TC1765
#                 h
#                 src
#               TriBoard-TC1766
#               TriBoard-TC1775
#                 h
#                 src
#               TriBoard-TC1792
#                 h
#                 src
#               TriBoard-TC1796
#                 h
#                 src
#               TriBoard-TC1797
#                 h
#                 src
#               TriBoard-TC1920
#                 h
#                 src
#           win32gui
#             files
#               dialog
#               frame
#           wxwidgets
#             common
#             pch
#             rc
#             wxfb
#               dialog
#               frame
#             wxsmith
# Demos
#   HelloWorld
#     bin
#       Debug
#     include
#     obj
#       Debug
#         src
#     src
# DependencyTreeDemo
#   .git
#     hooks
#     info
#     logs
#       refs
#         heads
#     objects
#       03
#       05
#       07
#       09
#       0e
#       18
#       1b
#       1d
#       1f
#       27
#       29
#       2b
#       2c
#       35
#       38
#       3c
#       3d
#       3f
#       41
#       42
#       47
#       4a
#       4c
#       4d
#       4e
#       4f
#       50
#       55
#       5b
#       5c
#       60
#       61
#       66
#       67
#       69
#       6a
#       6c
#       71
#       73
#       77
#       78
#       7a
#       7c
#       83
#       8a
#       90
#       91
#       92
#       95
#       98
#       99
#       9d
#       9e
#       9f
#       a3
#       a6
#       b1
#       b4
#       b5
#       ba
#       bc
#       be
#       c1
#       c3
#       c5
#       cf
#       d1
#       d4
#       d5
#       d9
#       db
#       dc
#       e3
#       e4
#       e9
#       ea
#       f0
#       f1
#       info
#       pack
#     refs
#       heads
#       tags
#   .vs
#     DependencyTreeDemo
#       v15
#         sqlite3
#   DependencyTreeDriver
#     Properties
#   DependencyTreeLib
#     Properties
#   DependencyTreeTest
#     Properties
#   packages
#     MSTest.TestAdapter.1.1.18
#       build
#         net45
#         netcoreapp1.0
#         uap10.0
#         _common
#           cs
#           de
#           es
#           fr
#           it
#           ja
#           ko
#           pl
#           pt
#           ru
#           tr
#           zh-Hans
#           zh-Hant
#     MSTest.TestFramework.1.1.18
#       lib
#         net45
#           cs
#           de
#           es
#           fr
#           it
#           ja
#           ko
#           pl
#           pt
#           ru
#           tr
#           zh-Hans
#           zh-Hant
#         netstandard1.0
#           cs
#           de
#           es
#           fr
#           it
#           ja
#           ko
#           pl
#           pt
#           ru
#           tr
#           zh-Hans
#           zh-Hant
#         uap10.0
#           cs
#           de
#           es
#           fr
#           it
#           ja
#           ko
#           pl
#           pt
#           ru
#           tr
#           zh-Hans
#           zh-Hant
#   TestResults
#     Deploy_bruce 2017-09-06 21_22_47
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_23_15
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_23_27
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_23_41
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_26_12
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_26_16
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_34_08
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_35_49
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_37_43
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_40_11
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 21_40_43
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 22_32_38
#       In
#         SURFACEPRO3
#       Out
#     Deploy_bruce 2017-09-06 22_33_11
#       In
#         SURFACEPRO3
#       Out
# DOS Compilers
#   BISON
#   FLEX
#   FORTRAN
#     APPENDIX
#     MAT265
#     ONOT
#   MASM_4
#     TEMP
#   TC
#     ACM96
#     ASM
#     BGI
#     BIN
#     BMP2BGI
#     CLASSLIB
#       EXAMPLES
#       INCLUDE
#       LIB
#       SOURCE
#     Copy of DISKBALL
#       test
#     csc219
#     CSC269
#     csc319
#       01
#       02a
#       02b
#     CSC490
#     DISKBALL
#       test
#     EXAMPLES
#       STARTUP
#       TCALC
#     FINANCE
#     gardens
#       BITMAP
#       GAME
#       GENERAL
#       HEIGHT
#       JOYSTICK
#       LIGHT
#       OPTIMIZE
#       POLYGONS
#       RAYCAST
#       RAYTRACE
#       WIREMAZE
#     GIFSTUFF
#     INCLUDE
#       SYS
#     KARATE
#     LIB
#     MAT265
#     MENU
#     PARSER
#     POWGRAPH
#     PROGRAMS
#     SBP
#     TASM
#     tester
#     TOUR
#   TP
#     CGA
#     DISKSTUF
#     EGA
#     EXAMPLES
#     EXE1
#     EXE2
#     GC
#       test
#     HERC
#     HOLM
#     POWGRAPH
#     PROGRAMS
#       BIBLI
#       COMAMT
#       DATETIME
#       DTD
#       ELEMPTR
#       FILEATTR
#       LINEEDIT
#       MOVIE
#       MOVIEPTR
#       MUSICPTR
#       PARSER
#       PHONE
#       PHONEPTR
#       POINTER
#       RDI
#       SINK
#       SW50
#       VC
#       VGATREK
#     TEMP
#     TEST
#     TOOLBOX
# eclipse-workspace
#   .metadata
#     .mylyn
#       .taskListIndex
#       contexts
#     .plugins
#       org.eclipse.buildship.core
#       org.eclipse.core.resources
#         .history
#           17
#           18
#           22
#           24
#           26
#           27
#           2e
#           2f
#           33
#           36
#           37
#           38
#           39
#           3a
#           3e
#           3f
#           4
#           48
#           4c
#           4e
#           4f
#           52
#           5a
#           5e
#           6
#           60
#           63
#           6a
#           6e
#           6f
#           70
#           71
#           75
#           78
#           7a
#           7c
#           7d
#           8
#           83
#           84
#           86
#           87
#           88
#           8b
#           8d
#           8e
#           8f
#           91
#           92
#           93
#           97
#           98
#           9d
#           9f
#           a
#           a0
#           a2
#           a8
#           a9
#           aa
#           b
#           b1
#           b7
#           b9
#           c
#           c0
#           c5
#           c6
#           cb
#           d0
#           d1
#           d3
#           d6
#           d7
#           d9
#           db
#           de
#           e0
#           e4
#           e7
#           e8
#           ee
#           ef
#           f0
#           f2
#           f7
#           fb
#         .projects
#           LeagueLevel1Extras
#             .indexes
#               af
#               e4
#             org.eclipse.jdt.apt.core
#             org.eclipse.jdt.core
#           Level0-Module0
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.apt.core
#             org.eclipse.jdt.core
#           Level0-Module1
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.core
#           Level0-Module2
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.core
#           Level0-Module3
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.core
#           Level0-Module4
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.core
#           Level0-Module5
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.core
#           Level1-Module0
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.apt.core
#             org.eclipse.jdt.core
#           Level1-Module1
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.core
#           Level1-Module2
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.apt.core
#             org.eclipse.jdt.core
#           Level1-Module3
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.apt.core
#             org.eclipse.jdt.core
#           Level1-Module3-Old
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.apt.core
#             org.eclipse.jdt.core
#           Level1-Module4
#             .indexes
#             org.eclipse.egit.core
#             org.eclipse.jdt.core
#         .root
#           .indexes
#         .safetable
#       org.eclipse.core.runtime
#         .settings
#       org.eclipse.debug.core
#         .launches
#       org.eclipse.debug.ui
#       org.eclipse.e4.workbench
#       org.eclipse.eclemma.core
#         .execdata
#       org.eclipse.egit.ui
#       org.eclipse.emf.common.ui
#       org.eclipse.epp.logging.aeri.ide
#         org.eclipse.epp.logging.aeri.ide.server
#           http-cache.lucene60
#           local-history.lucene60
#       org.eclipse.equinox.p2.ui
#       org.eclipse.jdt.core
#       org.eclipse.jdt.junit.core
#         history
#       org.eclipse.jdt.launching
#       org.eclipse.jdt.ui
#       org.eclipse.ltk.core.refactoring
#         .refactorings
#           .workspace
#             2018
#               10
#                 43
#               11
#                 46
#               12
#                 49
#           Level1-Module0
#             2018
#               11
#                 46
#           Level1-Module3
#             2018
#               11
#                 46
#       org.eclipse.ltk.ui.refactoring
#       org.eclipse.m2e.logback.configuration
#       org.eclipse.mylyn.bugzilla.core
#       org.eclipse.mylyn.commons.notifications.ui
#       org.eclipse.mylyn.context.core
#         contexts
#       org.eclipse.mylyn.tasks.ui
#       org.eclipse.oomph.setup
#       org.eclipse.oomph.setup.ui
#       org.eclipse.recommenders.news.impl
#         downloads
#       org.eclipse.tips.ide
#       org.eclipse.ui.editors
#       org.eclipse.ui.ide
#       org.eclipse.ui.intro
#       org.eclipse.ui.workbench
#       org.eclipse.ui.workbench.texteditor
#       org.eclipse.userstorage.oauth
#   .recommenders
#     caches
#     index
#       http___download_eclipse_org_recommenders_models_photon_
#   LeagueLevel1Extras
#     .settings
#     bin
#     src
# InfiniteRoot
#   InfiniteRoot.MathStax
#     Assets
#       Backgrounds
#         Formatted
#       freesound.org
#         136765__mitchelk__explode001_data
#           e00
#             d00
#         Tada_data
#           e00
#             d00
#       Help
#       Medals
#       Music
#     Debug
#     InfiniteRoot.MathStax
#       InfiniteRoot.MathStax
#         Assets
#         Bin
#           Debug
#             Content
#             MDIL
#           Release
#             Content
#         Blox
#         Controls
#         Helpers
#         Images
#           Achievements
#           Help
#         obj
#           Debug
#             Blox
#             Controls
#             MDIL
#             Pages
#             Templates
#             TempPE
#           Release
#             Blox
#             Controls
#             Pages
#             Templates
#             TempPE
#         Pages
#         Properties
#         Resources
#         Templates
#       InfiniteRoot.MathStaxLib
#         bin
#           Windows Phone
#             Debug
#               Content
#             Release
#               Content
#         obj
#           Windows Phone
#             Debug
#               TempPE
#             Release
#               TempPE
#         Properties
#       InfiniteRoot.MathStaxLibContent
#         bin
#           Windows Phone
#             Debug
#             Release
#         obj
#           Windows Phone
#             Debug
#               TempPE
#             Release
#               TempPE
#         Properties
#     PhoneClassLibrary1
#       Bin
#         Debug
#         Release
#       obj
#         Debug
#           TempPE
#         Release
#           TempPE
#       Properties
#   InfiniteRoot.StaxSharedLibrary
#     Bin
#       Debug
#       Release
#     Controls
#     Geometry
#     Helpers
#     Images
#       Blox
#     obj
#       Debug
#         Controls
#         TempPE
#       Release
#         Controls
#         TempPE
#     Properties
#     XnaContents
#     XnaObjects
#   InfiniteRoot.WordStax
#     Assets
#       Medals
#       Sounds
#     InfiniteRoot.WordStax
#       Assets
#       Bin
#         Debug
#           Content
#           Fonts
#         Release
#       Fonts
#       Helpers
#       Images
#         Achievements
#       obj
#         Debug
#           Pages
#           Templates
#           TempPE
#       Pages
#       Properties
#       Templates
#       WordLists
#     InfiniteRoot.WordStaxLib
#       bin
#         Windows Phone
#           Debug
#             Content
#       obj
#         Windows Phone
#           Debug
#             TempPE
#       Properties
#     InfiniteRoot.WordStaxLibContent
#       bin
#         AnyCPU
#           Debug
#         Windows Phone
#           Debug
#         x86
#           Debug
#       obj
#         Debug
#           TempPE
#         Windows Phone
#           Debug
#         x86
#           Debug
#       Properties
#   WebSite
#     InfiniteRootWeb
#       App_Data
#       App_Start
#       bin
#         de
#         es
#         fr
#         it
#         ja
#         ko
#         ru
#         zh-Hans
#         zh-Hant
#       Content
#         Images
#           MathStax
#         themes
#           base
#             images
#             minified
#               images
#       Controllers
#       Filters
#       Images
#       Models
#       obj
#         Debug
#           TempPE
#           __testMsDeployConnection__
#         Release
#           Package
#             PackageTmp
#               bin
#                 de
#                 es
#                 fr
#                 it
#                 ja
#                 ko
#                 ru
#                 zh-Hans
#                 zh-Hant
#               Content
#                 Images
#                   MathStax
#                 themes
#                   base
#                     images
#                     minified
#                       images
#               Images
#               Scripts
#               Views
#                 Account
#                 Home
#                 LearningCSharp
#                 MobileApps
#                 Services
#                 Shared
#           ProfileTransformWebConfig
#             transformed
#               Views
#           TempPE
#           TransformWebConfig
#             assist
#             original
#             transformed
#               Views
#       Properties
#         PublishProfiles
#       Scripts
#       Views
#         Account
#         Home
#         LearningCSharp
#         MobileApps
#         Services
#         Shared
#     packages
#       DotNetOpenAuth.AspNet.4.1.4.12333
#         lib
#           net40-full
#           net45-full
#       DotNetOpenAuth.Core.4.1.4.12333
#         lib
#           net40-full
#           net45-full
#       DotNetOpenAuth.OAuth.Consumer.4.1.4.12333
#         lib
#           net40-full
#           net45-full
#       DotNetOpenAuth.OAuth.Core.4.1.4.12333
#         lib
#           net40-full
#           net45-full
#       DotNetOpenAuth.OpenId.Core.4.1.4.12333
#         lib
#           net40-full
#           net45-full
#       DotNetOpenAuth.OpenId.RelyingParty.4.1.4.12333
#         lib
#           net40-full
#           net45-full
#       EntityFramework.5.0.0
#         Content
#         lib
#           net40
#           net45
#         tools
#       jQuery.1.8.2
#         Content
#           Scripts
#         Tools
#       jQuery.UI.Combined.1.8.24
#         Content
#           Content
#             themes
#               base
#                 images
#                 minified
#                   images
#           Scripts
#         Tools
#       jQuery.Validation.1.10.0
#         Content
#           Scripts
#       knockoutjs.2.2.0
#         Content
#           Scripts
#       Microsoft.AspNet.Mvc.4.0.20710.0
#         lib
#           net40
#       Microsoft.AspNet.Mvc.FixedDisplayModes.1.0.0
#         lib
#           net40
#       Microsoft.AspNet.Razor.2.0.20715.0
#         lib
#           net40
#       Microsoft.AspNet.Web.Optimization.1.0.0
#         lib
#           net40
#       Microsoft.AspNet.WebApi.4.0.20710.0
#       Microsoft.AspNet.WebApi.Client.4.0.20710.0
#         lib
#           net40
#       Microsoft.AspNet.WebApi.Core.4.0.20710.0
#         content
#         lib
#           net40
#       Microsoft.AspNet.WebApi.OData.4.0.0
#         lib
#           net40
#       Microsoft.AspNet.WebApi.WebHost.4.0.20710.0
#         lib
#           net40
#       Microsoft.AspNet.WebPages.2.0.20710.0
#         lib
#           net40
#       Microsoft.AspNet.WebPages.Data.2.0.20710.0
#         lib
#           net40
#       Microsoft.AspNet.WebPages.OAuth.2.0.20710.0
#         lib
#           net40
#       Microsoft.AspNet.WebPages.WebData.2.0.20710.0
#         lib
#           net40
#       Microsoft.Data.Edm.5.2.0
#         lib
#           net40
#             de
#             es
#             fr
#             it
#             ja
#             ko
#             ru
#             zh-Hans
#             zh-Hant
#           sl4
#             de
#             es
#             fr
#             it
#             ja
#             ko
#             ru
#             zh-Hans
#             zh-Hant
#       Microsoft.Data.OData.5.2.0
#         lib
#           net40
#             de
#             es
#             fr
#             it
#             ja
#             ko
#             ru
#             zh-Hans
#             zh-Hant
#           sl4
#             de
#             es
#             fr
#             it
#             ja
#             ko
#             ru
#             zh-Hans
#             zh-Hant
#       Microsoft.jQuery.Unobtrusive.Ajax.2.0.30116.0
#         Content
#           Scripts
#       Microsoft.jQuery.Unobtrusive.Validation.2.0.30116.0
#         Content
#           Scripts
#       Microsoft.Net.Http.2.0.20710.0
#         lib
#           net40
#           net45
#       Microsoft.Web.Infrastructure.1.0.0.0
#         lib
#           net40
#       Modernizr.2.6.2
#         Content
#           Scripts
#         Tools
#       Newtonsoft.Json.4.5.11
#         lib
#           net20
#           net35
#           net40
#           portable-net40%2Bsl4%2Bwp7%2Bwin8
#           sl3-wp
#           sl4
#           sl4-windowsphone71
#           winrt45
#       System.Spatial.5.2.0
#         lib
#           net40
#             de
#             es
#             fr
#             it
#             ja
#             ko
#             ru
#             zh-Hans
#             zh-Hant
#           sl4
#             de
#             es
#             fr
#             it
#             ja
#             ko
#             ru
#             zh-Hans
#             zh-Hant
#       WebGrease.1.3.0
#         lib
#         tools
# processing-3.4
#   core
#     library
#   java
#     bin
#       dtplugin
#       plugin2
#       server
#     lib
#       amd64
#       applet
#       cmm
#       deploy
#       ext
#       fonts
#       images
#         cursors
#       jfr
#       management
#       security
#         policy
#           limited
#           unlimited
#   lib
#     fonts
#     footer
#     icons
#     languages
#     manager
#     status
#     toolbar
#     welcome
#   modes
#     java
#       .externalToolBuilders
#       .settings
#       application
#         launch4j
#           bin
#           head
#           lib
#           w32api
#         template.app
#           Contents
#             MacOS
#             Resources
#       bin
#         antlr
#         processing
#           mode
#             java
#               debug
#               pdex
#               preproc
#               runner
#               tweak
#       examples
#         Basics
#           Arrays
#             Array
#             Array2D
#             ArrayObjects
#           Camera
#             MoveEye
#             Orthographic
#             Perspective
#           Color
#             Brightness
#             ColorVariables
#             Hue
#             LinearGradient
#             RadialGradient
#             Relativity
#             Saturation
#             WaveGradient
#           Control
#             Conditionals1
#             Conditionals2
#             EmbeddedIteration
#             Iteration
#             LogicalOperators
#           Data
#             CharactersStrings
#               data
#             DatatypeConversion
#               data
#             IntegersFloats
#             TrueFalse
#             Variables
#             VariableScope
#           Form
#             Bezier
#             PieChart
#             PointsLines
#             Primitives3D
#             RegularPolygon
#             ShapePrimitives
#             Star
#             TriangleStrip
#           Image
#             Alphamask
#               data
#             BackgroundImage
#               data
#             CreateImage
#             LoadDisplayImage
#               data
#             Pointillism
#               data
#             RequestImage
#               data
#             Transparency
#               data
#           Input
#             Clock
#             Constrain
#             Easing
#             Keyboard
#             KeyboardFunctions
#             Milliseconds
#             Mouse1D
#             Mouse2D
#             MouseFunctions
#             MousePress
#             MouseSignals
#             StoringInput
#           Lights
#             Directional
#             Mixture
#             MixtureGrid
#             OnOff
#             Reflection
#             Spot
#           Math
#             AdditiveWave
#             Arctangent
#             Distance1D
#             Distance2D
#             DoubleRandom
#             Graphing2DEquation
#             IncrementDecrement
#             Interpolate
#             Map
#             Noise1D
#             Noise2D
#             Noise3D
#             NoiseWave
#             OperatorPrecedence
#             PolarToCartesian
#             Random
#             RandomGaussian
#             Sine
#             SineCosine
#             SineWave
#           Objects
#             CompositeObjects
#             Inheritance
#             MultipleConstructors
#             Objects
#           Shape
#             DisableStyle
#               data
#             GetChild
#               data
#             LoadDisplayOBJ
#               data
#             LoadDisplaySVG
#               data
#             ScaleShape
#               data
#             ShapeVertices
#               data
#           Structure
#             Coordinates
#             CreateGraphics
#               data
#             Functions
#             Loop
#             NoLoop
#             Recursion
#             Redraw
#             SetupDraw
#             StatementsComments
#             WidthHeight
#           Transform
#             Arm
#             Rotate
#             RotatePushPop
#             RotateXY
#             Scale
#             Translate
#           Typography
#             Letters
#               data
#             Words
#               data
#           Web
#             EmbeddedLinks
#             LoadingImages
#         Demos
#           Graphics
#             DepthSort
#             LowLevelGLVboInterleaved
#               data
#             LowLevelGLVboSeparate
#               data
#             MeshTweening
#               data
#             Particles
#               data
#             Patch
#             Planets
#               data
#             Ribbons
#               data
#             RotatingArcs
#             Trefoil
#               data
#             Wiggling
#             Yellowtail
#           Performance
#             CubicGridImmediate
#             CubicGridRetained
#             DynamicParticlesImmediate
#               data
#             DynamicParticlesRetained
#               data
#             Esfera
#             LineRendering
#             QuadRendering
#             StaticParticlesImmediate
#               data
#             StaticParticlesRetained
#               data
#             TextRendering
#           Tests
#             MultipleWindows
#             NoBackgroundTest
#             OffscreenTest
#             RedrawTest
#             ResizeTest
#             SpecsTest
#         Topics
#           Advanced Data
#             ArrayListClass
#             CountingStrings
#               data
#             HashMapClass
#               data
#             IntListLottery
#             LoadSaveJSON
#               data
#             LoadSaveTable
#               data
#             LoadSaveXML
#               data
#             Regex
#             Threads
#             XMLYahooWeather
#               data
#           Animation
#             AnimatedSprite
#               data
#             Sequential
#               data
#           Cellular Automata
#             GameOfLife
#             Spore1
#             Spore2
#             Wolfram
#           Create Shapes
#             BeginEndContour
#             GroupPShape
#             ParticleSystemPShape
#               data
#             PathPShape
#             PolygonPShape
#             PolygonPShapeOOP
#             PolygonPShapeOOP2
#             PolygonPShapeOOP3
#             PrimitivePShape
#             WigglePShape
#           Curves
#             ArcLengthParametrization
#           Drawing
#             ContinuousLines
#             Pattern
#             Pulses
#           File IO
#             DirectoryList
#             LoadFile1
#               data
#             LoadFile2
#               data
#             SaveFile1
#             SaveFile2
#             SaveFrames
#             SaveOneFrame
#             TileImages
#           Fractals and L-Systems
#             Koch
#             Mandelbrot
#             PenroseSnowflake
#             PenroseTile
#             Pentigree
#             Tree
#           Geometry
#             Icosahedra
#             NoiseSphere
#             RGBCube
#             ShapeTransform
#             SpaceJunk
#             Toroid
#             Vertices
#           GUI
#             Button
#             Handles
#             Rollover
#             Scrollbar
#               data
#           Image Processing
#             Blending
#               data
#             Blur
#               data
#             Brightness
#               data
#             Convolution
#               data
#             EdgeDetection
#               data
#             Explode
#               data
#             Extrusion
#               data
#             Histogram
#               data
#             LinearImage
#               data
#             PixelArray
#               data
#             Zoom
#               data
#           Interaction
#             Follow1
#             Follow2
#             Follow3
#             Reach1
#             Reach2
#             Reach3
#             Tickle
#               data
#           Motion
#             Bounce
#             BouncyBubbles
#             Brownian
#             CircleCollision
#             CubesWithinCube
#             Linear
#             Morph
#             MovingOnCurves
#             Reflection1
#             Reflection2
#           Shaders
#             BlurFilter
#               data
#             Conway
#               data
#             CustomBlend
#               data
#             Deform
#               data
#             DomeProjection
#               data
#             EdgeDetect
#               data
#             EdgeFilter
#               data
#             GlossyFishEye
#               data
#             ImageMask
#               data
#             InfiniteTiles
#               data
#             Landscape
#               data
#             Monjori
#               data
#             Nebula
#               data
#             SepBlur
#               data
#             ToonShading
#               data
#           Simulate
#             Chain
#             Flocking
#             ForcesWithVectors
#             GravitationalAttraction3D
#             MultipleParticleSystems
#             SimpleParticleSystem
#             SmokeParticleSystem
#               data
#             SoftBody
#             Spring
#             Springs
#           Textures
#             TextureCube
#               data
#             TextureCylinder
#               data
#             TextureQuad
#               data
#             TextureSphere
#               data
#             TextureTriangle
#               data
#           Vectors
#             AccelerationWithVectors
#             BouncingBall
#             VectorMath
#       generated
#         processing
#           mode
#             java
#               preproc
#       libraries
#         dxf
#           .settings
#           bin
#             processing
#               dxf
#           examples
#             SimpleExport
#           library
#           src
#             processing
#               dxf
#         io
#           examples
#             AnalogDigital_I2C_ADS1X15
#             AnalogDigital_SPI_MCP3001
#             AnalogDigital_SPI_MCP3008
#             Compass_I2C_HMC6352
#             DigitalAnalog_I2C_MCP4725
#             Display_I2C_SSD1306
#             Environment_I2C_BME280
#             Interrupt
#             LedCounter
#             Light_I2C_TSL2561
#             Servo_I2C_PCA9685
#             SimpleI2C
#             SimpleInput
#             SimpleOutput
#             SimpleResistorSensor
#             SimpleSPI
#             SoftwareServoSweep
#             Touch_I2C_MPR121
#           library
#             linux-arm64
#             linux-armv6hf
#             linux32
#             linux64
#           src
#             native
#             processing
#               io
#         net
#           .settings
#           bin
#             processing
#               net
#           examples
#             ChatServer
#               data
#             HTTPClient
#             SharedCanvasClient
#             SharedCanvasServer
#           library
#           src
#             processing
#               net
#         pdf
#           .settings
#           bin
#             processing
#               pdf
#           examples
#             Complex3D
#             LargePage
#             ManyPages
#             ManyPDFs
#             MousePress
#             MultipleFrames
#             OneFrame
#             RandomBook
#           library
#           src
#             processing
#               pdf
#         serial
#           .settings
#           bin
#             processing
#               serial
#           examples
#             SerialCallResponse
#             SerialDuplex
#               data
#             SerialMultiple
#             SimpleRead
#             SimpleWrite
#           library
#             linux-arm64
#             linux-armv6hf
#             linux32
#             linux64
#             macosx
#             windows32
#             windows64
#           src
#             processing
#               serial
#           test
#             serial_latency
#               arduino
#             serial_throughput
#               arduino
#         svg
#           bin
#             processing
#               svg
#           library
#           src
#             processing
#               svg
#       mode
#       reference
#         css
#           fonts
#         environment
#           images
#         images
#         img
#           about
#         javascript
#         libraries
#           dxf
#           images
#           io
#           net
#           pdf
#           serial
#           sound
#           video
#         people
#         tools
#           images
#       src
#         antlr
#         processing
#           mode
#             java
#               debug
#               pdex
#               preproc
#               runner
#               tweak
#       theme
#         completion
#         debug
#   tools
#     MovieMaker
#       bin
#         ch
#           randelshofer
#             gui
#               datatransfer
#             io
#             media
#               mp3
#               quicktime
#         processing
#           app
#             tools
#       src
#         ch
#           randelshofer
#             gui
#               datatransfer
#             io
#             media
#               mp3
#               quicktime
#         processing
#           app
#             tools
#       tool
# Python
#   datarepo
#     matplotlib-challenge
#       Instructions
#         Images
#         Pyber
#           .ipynb_checkpoints
#           data
#         Pymaceuticals
#           data
#     pandas-challenge
#       HeroesOfPymoli
#         .ipynb_checkpoints
#         Resources
#       Images
#       PyCitySchools
#         Resources
#     UCSD201809DATA4
#       .git
#         hooks
#         info
#         logs
#           refs
#             heads
#             remotes
#               origin
#         objects
#           01
#           05
#           0f
#           12
#           17
#           22
#           23
#           26
#           2a
#           2c
#           2d
#           2e
#           36
#           37
#           41
#           43
#           45
#           49
#           50
#           55
#           59
#           5d
#           5e
#           62
#           6b
#           75
#           7b
#           84
#           85
#           8b
#           8c
#           91
#           92
#           96
#           99
#           9b
#           a0
#           b1
#           b2
#           ba
#           bb
#           c0
#           c4
#           c5
#           d1
#           de
#           e8
#           ef
#           f2
#           f8
#           fa
#           fe
#           info
#           pack
#         refs
#           heads
#           remotes
#             origin
#           tags
#       00-Prework
#         docs
#           modules
#             assets
#       01-Lesson-Plans
#         01-Excel
#           1
#             Activities
#               01-Ins_GreatDebate
#                 Resources
#                 Solved
#           2
#             Activities
#               01-Ins_ExcelPlayground
#                 Solved
#                 Unsolved
#               02-Ins_NamedRanges
#                 Solved
#                 Unsolved
#               03-Ins_ColorCounter
#                 Solved
#                 Unsolved
#               04-Stu_GradeBook
#                 Solved
#                 Unsolved
#               05-Ins_MultipleWorksheets
#                 Solved
#                 Unsolved
#               06-Stu_ApplesAndOranges
#                 Solved
#                 Unsolved
#               07-Ins_Formatting
#                 Solved
#                 Unsolved
#               08-Stu_McDonaldsFormat
#                 Solved
#                 Unsolved
#               09-Ins_PivotTables
#                 Solved
#                 Unsolved
#               10-Stu_TopSongsPivot
#                 Solved
#                 Unsolved
#               11-Ins_Lookups
#                 Solved
#                 Unsolved
#               12-Stu_ProductPivot
#                 Solved
#                 Unsolved
#             Extra_Content
#               Ins_Intro_Solver
#                 Solved
#                 Unsolved
#               Stu_Shipment
#                 Solved
#                 Unsolved
#           3
#             Activities
#               01-Ins_GitHub
#                 Resources
#                 Solved
#               02-Ins_BasicCharting
#                 Solved
#                 Unsolved
#               03-Stu_LineAndBar
#                 Solved
#                 Unsolved
#               04-Ins_ScatterPlot
#                 Solved
#                 Unsolved
#               05-Par_GameSales
#                 Solved
#                 Unsolved
#               06-Evr_PigeonRacing
#                 Solved
#                 Unsolved
#               07-Par_FilterGameSales
#                 Solved
#                 Unsolved
#               08-Ins_MovingAverages
#                 Solved
#                 Unsolved
#               09-Stu_GolfingTargets
#                 Solved
#                 Unsolved
#               10-Ins_Regression
#                 Solved
#                 Unsolved
#               11-Stu_NBAStats
#                 Solved
#                 Unsolved
#             Extra_Content
#               Activities
#                 Extra_Stu_IceCreamFaves
#                   Solved
#                   Unsolved
#         02-VBA-Scripting
#           1
#             Activities
#               01-Ins_HelloWorld
#                 Solved
#                 Unsolved
#               02-Stu_HelloVBA
#                 Solved
#                 Unsolved
#               03-Ins_ButtonClicks
#                 Solved
#                 Unsolved
#               04-Stu_ChooseYourButton
#                 Solved
#                 Unsolved
#               05-Ins_CellsAndRanges
#                 Solved
#                 Unsolved
#               06-Stu_ChessBoard
#                 Images
#                 Solved
#                 Unsolved
#               07-Ins_Variables
#                 Solved
#                 Unsolved
#               08-Stu_TotalCalculator
#                 Solved
#                 Unsolved
#               09-Ins_Arrays
#                 Solved
#                 Unsolved
#               10-Ins_Splitting
#                 Solved
#                 Unsolved
#               11-Stu_SentenceBreaker
#                 Solved
#                 Unsolved
#               12-Ins_Conditionals
#                 Solved
#                 Unsolved
#               13-Stu_ChooseYourStory
#                 Solved
#                 Unsolved
#             Images
#           2
#             Activities
#               01-Stu_Warmup
#                 Solved
#                 Unsolved
#               02-Ins_ForLoops
#                 Solved
#                 Unsolved
#               03-Stu_ChickenNuggets
#                 Solved
#                 Unsolved
#               04-Ins_LoopConditionals
#                 Solved
#                 Unsolved
#               05-Stu_FizzBuzz
#                 Solved
#                 Unsolved
#               06-Stu_Lotto
#                 Solved
#                 Unsolved
#               07-Ins_NestedForLoops
#                 Solved
#                 Unsolved
#               08-Stu_HornetsNest
#                 Solved
#                 Unsolved
#             Images
#           3
#             Activities
#               01-Stu_StarsCounter
#                 Solved
#                 Unsolved
#               02-Ins_Formatter
#                 Solved
#               03-Stu_Gradebook
#                 Solved
#                 Unsolved
#               04-Stu_Checkerboard
#                 Solved
#                 Unsolved
#               05-Ins_NextCells
#                 Solved
#               06-Stu_CreditCardChecker
#                 Solved
#                 Unsolved
#               07-Stu_WellsFargo_Pt1
#                 Solved
#                 Unsolved
#                   RAW
#               08-Stu_WellsFargo_Pt2
#                 Solved
#                 Unsolved
#               Extra_Content
#                 07-Ins_Multisheet
#                   Resources
#                 08-Ins_Mutlifunction
#                   Resources
#                 09-Stu_MultiGames
#                   Functions
#                     Resources
#                     Solved
#                   Sheets
#                     Resources
#                     Solved
#             Images
#         03-Python
#           1
#             Activities
#               01-Ins_Terminal
#                 Solved
#                 Unsolved
#               02-Stu_TerminalTest
#                 Solved
#                 Unsolved
#               03-Ins_Variables
#                 Solved
#               04-Stu_HelloVariableWorld
#                 Solved
#                 Unsolved
#               05-Ins_Prompts
#                 Solved
#               06-Stu_DownToInput
#                 Solved
#                 Unsolved
#               07-Ins_Conditionals
#                 Solved
#               08-Stu_ConditionalConundrum
#                 Solved
#                 Unsolved
#               09-Ins_List
#                 Solved
#               10-Stu_RockPaperScissors
#                 Solved
#                 Unsolved
#               11-Ins_Loops
#                 Solved
#               12-Stu_NumberChain
#                 Solved
#                 Unsolved
#             Images
#           2
#             Activities
#               01-Stu_QuickCheckup
#                 Solved
#                 Unsolved
#               02-Ins_SimpleLoops
#                 Solved
#                 Unsolved
#               03-Stu_KidInCandyStore
#                 Solved
#                 Unsolved
#               04-Stu_HouseOfPies
#                 Solved
#                 Unsolved
#               05-Ins_BasicRead
#                 Resources
#                 Solved
#                 Unsolved
#               06-Ins_Modules
#                 Solved
#                 Unsolved
#               07-Ins_ReadCSV
#                 Resources
#                 Solved
#                 Unsolved
#               08-Stu_ReadNetFlix
#                 Resources
#                 Solved
#                 Unsolved
#               09-Ins_WriteCSV
#                 output
#                 Solved
#                 Unsolved
#               10-Ins_Zip
#                 Solved
#                 Unsolved
#               11-Stu_UdemyZip
#                 Resources
#                 Solved
#                 Unsolved
#               12-Ins_Functions
#                 Solved
#                 Unsolved
#             Images
#           3
#             Activities
#               01-Stu_CerealCleaner
#                 Resources
#                 Solved
#                 Unsolved
#               02-Ins_Dicts
#                 Images
#                 Solved
#                 Unsolved
#               03-Stu_HobbyBook
#                 Solved
#                 Unsolved
#               04-Evr_List_Comprehensions
#                 Solved
#                 Unsolved
#               05-Stu_List_Comprehensions
#                 Solved
#                 Unsolved
#               06-Evr_Functions
#                 Solved
#                 Unsolved
#               07-Stu_Functions
#                 Solved
#                 Unsolved
#               08-Par_WrestlingWithFunctions
#                 Resources
#                 Solved
#                 Unsolved
#             Extra_Content
#               ADVANCED_Ins_Set_Operations
#               ADVANCED_Stu_Resume_Analysis
#                 Solved
#                 Unsolved
#               ADVANCED_Stu_UUID_Generator
#                 Solved
#               Stu_Email
#                 Resources
#                 Solved
#                   output
#                 Unsolved
#             Images
#             Resources
#           Supplemental
#             Images
#         04-Pandas
#           1
#             Activities
#               01-Ins_JupyterIntro
#                 Solved
#               02-Stu_NetflixRemix
#                 Solved
#                   Resources
#                 Unsolved
#                   Resources
#               03-Ins_IntroToPandas
#                 Solved
#               04-Stu_DataFrameShop
#                 Solved
#                 Unsolved
#               05-Ins_DataFunctions
#                 Solved
#                   Resources
#               06-Stu_TrainingGrounds
#                 Solved
#                 Unsolved
#               07-Ins_ColumnManipulation
#                 Solved
#               08-Stu_Hey_Arnold
#                 Solved
#                   Output
#                 Unsolved
#               09-Ins_ReadingWritingCSV
#                 Solved
#                   Output
#                   Resources
#               10-Stu_GoodReads
#                 Solved
#                   Output
#                   Resources
#                 Unsolved
#                   Resources
#               11-Stu_GoodReadsSummary
#                 Solved
#                   Resources
#                 Unsolved
#                   Resources
#           2
#             Activities
#               01-Ins_LocAndIloc
#                 Solved
#                   Resources
#               02-Stu_GoodMovies
#                 Solved
#                   output
#                   Resources
#                 Unsolved
#                   output
#                   Resources
#               03-Ins_CleaningData
#                 Solved
#                   Resources
#               04-Par_PortlandCrime
#                 Solved
#                   Resources
#                 Unsolved
#                   Resources
#               05-Evr_PandasRecap
#                 Solved
#                   Resources
#                 Unsolved
#                   Resources
#               06-Ins_GroupBy
#                 Solved
#                   Resources
#               07-Par_Pokemon
#                 Solved
#                   output
#                   Resources
#                 Unsolved
#                   output
#                   Resources
#               08-Ins_Sorting
#                 Solved
#                   Resources
#               09-Stu_SearchForTheWorst
#                 Solved
#                   Resources
#                 Unsolved
#                   Resources
#             Images
#           3
#             Activities
#               01-Ins_Merging
#                 Solved
#               02-Stu_Cryptocurrency
#                 Solved
#                   .ipynb_checkpoints
#                   Resources
#                 Unsolved
#                   Resources
#               03-Ins_Binning
#                 Solved
#                   .ipynb_checkpoints
#                 Unsolved
#               04-Stu_TedTalks
#                 Solved
#                   Resources
#                 Unsolved
#                   Resources
#               05-Ins_Mapping
#                 Solved
#                   Resources
#               06-Stu_CleaningKickstarter
#                 Solved
#                   .ipynb_checkpoints
#                   Resources
#                 Unsolved
#                   Resources
#               07-Ins_IntroToBugfixing
#                 Solved
#                   Resources
#                 Unsolved
#                   Resources
# ...
#               02-Stu_SpaceX
#                 Solved
#                 Unsolved
#               03-Ins_ManipulatingResponses
#                 Solved
#                 Unsolved
#               04-Stu_FarFarAway
#                 Solved
#                 Unsolved
#               05-Par_NumberFacts
#                 Solved
#                 Unsolved
#               06-Ins_OMDbRequests
#                 Solved
#                 Unsolved
#               07-Stu_Explore_OMDb_API
#               08-Stu_MovieQuestions
#                 Solved
#                 Unsolved
#               09-Ins_IterativeRequests
#                 Solved
#                 Unsolved
#               10-Stu_MovieLoop
#                 Solved
#                 Unsolved
#               11-Ins_NYTAPI
#                 Solved
#                 Unsolved
#               12-Stu_RetrieveArticles
#                 Solved
#                 Unsolved
#             Extra_Content
#               00-Ins_Standard_Error
#               13-Stu_Combining_Data
#                 Solved
#             Images
#               Old Images
#           2
#             Activities
#               01-Stu_JSONTraversalReview
#                 Resources
#                 Solved
#                 Unsolved
#               02-Stu_RequestReview
#                 Solved
#                 Unsolved
#               03-Ins_OpenWeatherRequest
#                 Solved
#                 Unsolved
#               04-Stu_Bujumbura
#                 Solved
#                 Unsolved
#               05-Ins_OpenWeatherDataFrame
#                 Solved
#                 Unsolved
#               06-Stu_TVRatings
#                 Solved
#                 Unsolved
#               07-Ins_ExceptionHandling
#                 Solved
#                 Unsolved
#               08-Stu_MakingExceptions
#                 Solved
#                 Unsolved
#               09-Ins_OpenWeatherWrapper
#                 Solved
#                 Unsolved
#               10-Stu_MapWrap
#                 Resources
#                 Solved
#                 Unsolved
#               11-Ins_WorldBankAPI
#                 Solved
#                 Unsolved
#               12-Stu_TwoCalls
#                 Solved
#                 Unsolved
#               13-Ins_CitiPy
#                 Solved
#                 Unsolved
#             Extra_Content
#               Stu_CityPressure
#                 Solved
#                 Unsolved
#             Images
#               Jupyter Notebook Images
#               Old Images
#           3
#             Activities
#               01-Ins_Google_Geocode
#                 Solved
#                 Unsolved
#               02-Ins_Google_Places
#                 Solved
#                 Unsolved
#               03-Stu_Google_Drills
#                 Solved
#                 Unsolved
#               04-Ins_NearestRestr
#                 Resources
#                 Solved
#                 Unsolved
#               05-Stu_Google_Complex
#                 Resources
#                 Solved
#                 Unsolved
#               06-Evr_Jupyter_Gmaps
#                 Images
#                 Solved
#                 Unsolved
#               07-Stu_Airport_Map
#                 Images
#                 Resources
#                 Solved
#                 Unsolved
#               08-Ins_Census
#                 Solved
#                 Unsolved
#               09-Stu_Census
#                 Images
#                 Resources
#                 Solved
#                 Unsolved
#               10-Stu_BankDeserts_Heatmap
#                 Images
#                 Resources
#                 Solved
#                 Unsolved
#               Resources
#                 Images
#             Extra_Content
#               01-Stu_Wrapper_Recap
#                 Solved
#                 Unsolved
#             Images
#           Supplemental
#             Images
#         07-Project-1
#           1
#             Activities
#               01-Ins_Workflows
#                 Solved
#               02-Stu_Workflows
#                 Solved
#                 Unsolved
#               03-Ins_Branches
#                 Solved
#               04-Stu_Branches
#                 Solved
#                 Unsolved
#               05-Ins_Push
#                 Solved
#               06-Stu_Push
#                 Solved
#                 Unsolved
#             Images
#             ProjectGuidelines
#             Slide-Shows
#             Supplemental
#           2
#             Activities
#               01-Ins_Pull
#                 Solved
#               02-Stu_Pull
#                 Solved
#                 Unsolved
#               03-Evr_Merge
#                 Solved
#                 Unsolved
#               04-Evr_Pull_Requests
#                 Solved
#                 Unsolved
#             Images
#             Supplemental
#           3
#             Activities
#               01-Par_Null_Hypothesis
#                 Unsolved
#               02-Ins_TTest
#                 Solved
#                 Unsolved
#               03-Stu_Sardines
#                 Resources
#                 Solved
#                 Unsolved
#               04-Ins_ANOVA
#                 Resources
#                 Solved
#                 Unsolved
#               05-Stu_ANOVA
#                 Resources
#                 Solved
#                 Unsolved
#               06-Ins_Chi_Square
#                 Solved
#                 Unsolved
#               07-Stu_Chi_Square
#                 Solved
#                 Unsolved
#             Extra_Content
#               Activities
#                 01-Ins_Merge_Conflicts
#                 02-Stu_Merge_Conflicts
#                 03-Evr_Pull_Requests
#                 04-Stu_Stash
#               Images
#             Images
#             Slide-Shows
#             Supplemental
#         08-Project-1
#           1
#             Activities
#               01-Installation
#               Images
#             Images
#         09-SQL
#           1
#             Activities
#               01-Stu_CreateLocalhost
#                 Solved
#                 Unsolved
#               02-Ins_CreateDatabase
#                 Images
#                 Solved
#                 Unsolved
#               03-Ins_CreateTable
#                 Images
#                 Solved
#                 Unsolved
#               04-Stu_FavoriteDB
#                 Solved
#                 Unsolved
#               05-Ins_AddingRows
#                 Images
#                 Solved
#                 Unsolved
#               06-Stu_FavoriteDBData
#                 Solved
#                 Unsolved
#               07-Ins_ValueOfUniques
#                 Images
#                 Solved
#                 Unsolved
#               08-Stu_programmingDB
#                 Solved
#                 Unsolved
#               09-Ins_booksDB
#                 Solved
#                 Unsolved
#             Extra_Content
#               Activities
#                 01-Stu_BasicQueries
#                   Solved
#                   Unsolved
#                 02-Stu_ReviewsDB
#                   Solved
#                   Unsolved
#                 03-Stu_AddData
#                   Solved
#                   Unsolved
#                 04-Stu_MakeIDColumn
#                   Solved
#                   Unsolved
#                 05-Ins_UniqueValues
#                   Solved
#                   Unsolved
#             Images
#           2
#             Activities
#               01-Stu_Warmup
#                 Solved
#                 Unsolved
#               02-Ins_ImportWizard
#                 Resources
#                 Solved
#                 Unsolved
#               03-Ins_Intro_to_queries
#                 Resources
#                 Solved
#                 Unsolved
#               04-Stu_HideAndSeek
#                 Resources
#                 Solved
#                 Unsolved
#               05-Stu_SCUD
#                 Resources
#                 Solved
#                 Unsolved
#               06-Ins_WorkbenchGUI
#                 Resources
#                 Solved
#                 Unsolved
#               07-Ins_Joins
#                 Resources
#                 Solved
#                 Unsolved
#               08-Stu_JoiningTeam
#                 Resources
#                 Solved
#                 Unsolved
#               09-Par_SQLWitchcraft
#                 Resources
#                 Solved
#                 Unsolved
#             Images
#           3
#             Activities
#               01-Warmup
#                 Solved
#                 Unsolved
#               02-Stu_GregariousAggregates
#                 Solved
#                 Unsolved
#               03-Stu_Subqueries
#                 Solved
#                 Unsolved
#               04-Par_View_Room_Queries
#                 Images
#                 Solved
#                 Unsolved
#               05-Ins_Revisit_Subqueries
#                 Images
#                 Solved
#                 Unsolved
#               06-Stu_Mine_the_Subquery
#                 Solved
#                 Unsolved
#               07-Ins_Foreign_Keys
#                 Resources
#                 Solved
#                 Unsolved
#               08-Par_Foreign_Keys
#                 Solved
#                 Unsolved
#               09-Ins_Unions
#                 Solved
#                 Unsolved
#               10-Stu_Unions
#                 Solved
#                 Unsolved
#             Extra_Content
#               Activities
#                 10-Stu_Self_Joins
#                   Images
#                   Resources
#                   Solved
#                   Unsolved
#               Images
#             Images
#             Slide-Shows
#           Supplemental
#             Images
#         10-Advanced-Data-Storage-and-Retrieval
#           1
#             Activities
#               01-Ins_BasicSQL_Connection
#                 Resources
#                 Solved
#                 Unsolved
#               02-Stu_IceCreamStore
#                 Resources
#                 Solved
#                 Unsolved
#               03-Ins_ReadSQL
#                 Resources
#                 Solved
#                 Unsolved
#               04-Stu_ReadAllTheSQLs
#                 Resources
#                 Solved
#                 Unsolved
#               05-Ins_Preview_SQL_Alchemy
#                 Solved
#                 Unsolved
#               06-Ins_Classes
#                 Solved
#                 Unsolved
#               07-Stu_Surfer_Class
#                 Solved
#                 Unsolved
#               08-Ins_Classes_With_Methods
#                 Solved
#                 Unsolved
#               09-Stu_Surfer_Class_Extended
#                 Solved
#                 Unsolved
#               10-Ins_SQL_Alchemy_Revisited
#                 Solved
#                 Unsolved
#               11-Stu_Surfer_SQL
#                 Solved
#                 Unsolved
#             Images
#           2
#             Activities
#               01-Ins_Basic_Querying
#                 Resources
#                 Solved
#                 Unsolved
#               02-Stu_SharkSearch
#                 Resources
#                 Solved
#                 Unsolved
#               03-Ins_Basic_Updating
#                 Resources
#                 Solved
#                 Unsolved
#               04-Par_CruddyDB
#                 Solved
#                 Unsolved
#               05-Ins_Reflection
#                 Resources
#                 Solved
#                 Unsolved
#               06-Stu_ReflectingOnSQL
#                 Resources
#                 Solved
#                 Unsolved
#               07-Ins_Exploration
#                 Resources
#                 Solved
#                 Unsolved
#               08-Stu_SalaryExplore
#                 Resources
#                 Solved
#                 Unsolved
#               09-Par_EmojiPlotting
#                 Resources
#                 Solved
#                 Unsolved
#             Extra_Content
#               Activities
#                 01-Stu_Prescriptions
#                   Resources
#                   Solved
#                   Unsolved
#               Images
#             Images
#           3
#             Activities
#               01-Ins_Joins
#                 Resources
#                 Solved
#                 Unsolved
#               02-Ins_Dates
#                 Resources
#                 Solved
#                 Unsolved
#               03-Stu_Dates
#                 Resources
#                 Unsolved
#                   .ipynb_checkpoints
#               04-Ins_First_Steps_with_Flask
#                 Solved
#                 Unsolved
#               05-Stu_Hello_Web
#                 Unsolved
#               06-Ins_Jsonify
#                 Solved
#                 Unsolved
#               07-Stu_Justice_League
#                 Unsolved
#               08-Ins_Variable_Rule
#                 Solved
#                 Unsolved
#               09-Stu_Variable_Rule
#                 Unsolved
#               10-Ins_Flask_with_ORM
#                 Solved
#                 Unsolved
#               11-Stu_Chinook
#                 Resources
#                 Unsolved
#             Images
#           Generators
#       02-Homework
#         01-Excel
#           Instructions
#             Images
#           Solutions
#         02-VBA-Scripting
#           Instructions
#             Images
#             Resources
#           Solutions
#         03-Python
#           ExtraContent
#             Instructions
#               PyBoss
#                 Images
#               PyParagraph
#                 Images
#                 raw_data
#             Solutions
#               PyBoss
#                 analysis
#                 raw_data
#               PyParagraph
#                 analysis
#                 raw_data
#           Instructions
#             Images
#             PyBank
#               Resources
#             PyPoll
#               Resources
#           Solutions
#             HeroesOfPymoli
#               Resources
#             PyCitySchools
#               Resources
#                 Instruction_Example
#         04-Pandas
#           Instructions
#             HeroesOfPymoli
#               .ipynb_checkpoints
#               Resources
#             Images
#             PyCitySchools
#               Resources
#           Solutions
#             HeroesOfPymoli
#               Resources
#             PyCitySchools
#               Resources
#                 Instruction_Example
#         05-Matplotlib
#           Instructions
#             Images
#             Pyber
#               data
#             Pymaceuticals
#               data
#           Solutions
#             Pyber
#               analysis
#               data
#             Pymaceuticals
#               analysis
#               data
#                 test
#         06-Python-APIs
#           Instructions
#             Images
#             starter_code
#               .ipynb_checkpoints
#         09-SQL
#           Instructions
#             Images
#           Unsolved
#             Images
#         10-Advanced-Data-Storage-and-Retrieval
#           Instructions
#             Images
#             Resources
#     Yelp-Restaurant-Project
#       .git
#         hooks
#         info
#         logs
#           refs
#             heads
#             remotes
#               origin
#         objects
#           info
#           pack
#         refs
#           heads
#           remotes
#             origin
#           tags
#       Restaurant Competitors
#         figures
#       yelpProject
#         .ipynb_checkpoints
#         Resources
#           Carlsbad,CA
#           Encinitas,CA
#           Oceanside,CA
#           San Marcos,CA
#         ResourcesZip
#           Carlsbad,CA
#           Encinitas,CA
#           Oceanside,CA
#           San Marcos,CA
# VS.NET Projects
#   BESCalcXP
#     bin
#       Debug
#     obj
#       Debug
#         temp
#         TempPE
#   DataStructures
#     DataStructures
#       .vs
#         DataStructures
#           v15
#             Server
#               sqlite3
#       bin
#         Debug
#       obj
#         Debug
#           TempPE
#       Properties
#   OldCalcs
#     BESCalculator
#       bin
#       obj
#         Debug
#           temp
#           TempPE
#     GraphicCalculator
#       bin
#       obj
#         Debug
#           temp
#           TempPE
#       Pics
#   OmniMetrixXP
#     bin
#       Debug
#     obj
#       Debug
#         temp
#         TempPE
#     Pics
#   Parser
#     bin
#   PocketCalc
#     PocketCalc
#       bin
#         Debug
#       obj
#         Debug
#           temp
#           TempPE
#   UpdatedParser
# WordFinder
#   .vs
#     WordFinder
#       v15
#         Server
#           sqlite3
#   WordFinder
#     Assets
#     bin
#       ARM
#         Debug
#       x86
#         Debug
#     obj
#       ARM
#         Debug
#           intermediatexaml
#           TempPE
#       x86
#         Debug
#           intermediatexaml
#           TempPE
#     Properties

# %%
# To pass a variable number of arguments to function
def average(*args):
    '''
    Calculates the average of a set of numbers.

    Args:
        *args: Variable number of arguments
    Returns:
        Average of the numbers
    '''    
    if args is None or len(args) < 1:
        return math.nan
    total = 0
    for arg in args:  
        total += arg
    return total / len(args)

# %%
print(average())
# Out:
# nan

# %%
# Pass a variable number of key/value pairs (think dictionary)
def keywordArgs(**kwargs):
    '''
    Demonstrates how to pass an arbitrary number of keyword/value pairs to a function.

    Args:
        **kwargs: Variable number of keyword/value pair arguments
    Returns:
        None
    '''
    for key, value in kwargs.items(): 
        print (f"{key} = {value}")

# %%
keywordArgs(x = 1, y = 2, z = 3)
# Out:
# x = 1
# y = 2
# z = 3
